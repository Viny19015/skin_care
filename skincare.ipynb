# %%
# !nvidia-smi
# Out:
# Sun May  5 19:34:33 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.0/755.0 kB 10.6 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
# !pip install ultralytics
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.6 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.8/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/acne
# Out:
# /content/drive/MyDrive/Colab Notebooks/acne

# %%
ls
# Out:
# data/  data.yaml  runs/  yolov8m.pt  yolov8n.pt

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/acne/data
# Out:
# /content/drive/MyDrive/Colab Notebooks/acne/data

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/acne

# !yolo detect train data=data.yaml model=yolov8m.yaml pretrained=yolov8m.pt epochs=100 imgsz=640
# Out:
# /content/drive/MyDrive/Colab Notebooks/acne
# Transferred 475/475 items from pretrained weights
# Ultralytics YOLOv8.2.6 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo detect val model='/content/drive/MyDrive/Colab Notebooks/acne/runs/detect/train6/weights/best.pt' data=data.yaml
# Out:
# Ultralytics YOLOv8.2.6 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m summary (fused): 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/drive/MyDrive/Colab Notebooks/acne/data/valid/labels.cache... 56 images, 0 backgrounds, 0 corrupt: 100% 56/56 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:11<00:00,  2.96s/it]
#                    all         56        643      0.623      0.642      0.634        0.3
# Speed: 5.9ms preprocess, 41.4ms inference, 0.0ms loss, 66.9ms postprocess per image
# Results saved to runs/detect/val3
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo export model='/content/drive/MyDrive/Colab Notebooks/acne/runs/detect/train6/weights/best.pt' format=onnx
# Out:
# Ultralytics YOLOv8.2.6 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8m summary (fused): 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/Colab Notebooks/acne/runs/detect/train6/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (49.6 MB)
# requirements: Ultralytics requirement ['openvino>=2024.0.0'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.7/38.7 MB 244.8 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 8.5s, installed 1 package: ['openvino>=2024.0.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# OpenVINO: starting export with openvino 2024.1.0-15008-f4afc983258-releases/2024/1...
# OpenVINO: export success ✅ 17.5s, saved as '/content/drive/MyDrive/Colab Notebooks/acne/runs/detect/train6/weights/best_openvino_model/' (98.9 MB)
#
# Export complete (22.2s)
# ...

# %%
# !pip install tensorflow==2.13.1
# !pip install tflite_support==0.4.4
# Out:
# ...
# ERROR: Operation cancelled by user
# ...
